# %%
'''

你虽然是用autoreject处理过一遍了，但是毕竟是机器处理的，你还是不放心。

不知道为何，在NPS的时候，有的数据，基线很不好。


'''

import os.path as op
import mne
from mne.preprocessing import ICA
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %%
sub_id = 'prex006'
save_path_cleanepochs = 'E:\Python LYW\RSA\spaced_learning\pre10\preprocessing\data\\6epoch_clean\\'
clean_epochs=mne.read_epochs(save_path_cleanepochs + sub_id + '-epo.fif')
# Out:
# Reading E:\Python LYW\RSA\spaced_learning\pre10\preprocessing\data\6epoch_clean\prex06-epo.fif ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\SILVER~1\AppData\Local\Temp/ipykernel_20296/3231137583.py in <module>
#       1 sub_id = 'prex06'
#       2 save_path_cleanepochs = 'E:\Python LYW\RSA\spaced_learning\pre10\preprocessing\data\\6epoch_clean\\'
# ----> 3 clean_epochs=mne.read_epochs(save_path_cleanepochs + sub_id + '-epo.fif')
#
# <decorator-gen-228> in read_epochs(fname, proj, preload, verbose)
#
# D:\ProgramData\Anaconda3\envs\RSA\lib\site-packages\mne\epochs.py in read_epochs(fname, proj, preload, verbose)
#    3056         The epochs.
#    3057     """
# -> 3058     return EpochsFIF(fname, proj, preload, verbose)
#    3059
#    3060
#
# <decorator-gen-229> in __init__(self, fname, proj, preload, verbose)
#
# ...

# %%
# %matplotlib qt
clean_epochs.plot(n_epochs=3,n_channels=60,butterfly=True)
# Out:
# <MNEBrowseFigure size 1920x1027 with 4 Axes>

# %%
clean_epochs.plot_psd()
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
sub_id = 'prex006'
save_path_cleanepochs = 'E:\Python LYW\RSA\spaced_learning\pre10\preprocessing\data\\7evoked\\'
evoked=mne.read_epochs(save_path_cleanepochs + sub_id + '-ave.fif')
# Out:
# Reading E:\Python LYW\RSA\spaced_learning\pre10\preprocessing\data\7evoked\prex006-ave.fif ...
# C:\Users\SILVER~1\AppData\Local\Temp/ipykernel_20296/2895187184.py:3: RuntimeWarning: This filename (E:\Python LYW\RSA\spaced_learning\pre10\preprocessing\data\7evoked\prex006-ave.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   evoked=mne.read_epochs(save_path_cleanepochs + sub_id + '-ave.fif')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SILVER~1\AppData\Local\Temp/ipykernel_20296/2895187184.py in <module>
#       1 sub_id = 'prex006'
#       2 save_path_cleanepochs = 'E:\Python LYW\RSA\spaced_learning\pre10\preprocessing\data\\7evoked\\'
# ----> 3 evoked=mne.read_epochs(save_path_cleanepochs + sub_id + '-ave.fif')
#       4
#
# ...
